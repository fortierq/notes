# %%
# %load_ext autoreload
# %autoreload 2
from devoir import Devoir
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
d = Devoir("25", "notes25.xlsx")
d.mean("ds_1", 
    {"mpi": 11},
    {"mpi" : 3.5}
)
d.mean("ds_2", 
    {"mpi": 11},
    {"mpi" : 3.5}
)
d.mean("ds_3", 
    {"mpi": 11},
    {"mpi" : 3.25}
)
d.mean("ds_4", 
    {"mpi": 12},
    {"mpi" : 3.25}
)
dd = d.anonymize()
ds = "ds_4"
classe = "mpi"
# # dc = dd["option"]["2"]["df"].query("classe == 'mpp'")
dc = d.df[ds] #.query(f"classe == '{classe}' ")
print(dc[["note", "nom", "prenom"]].to_string(index=False))
print(dc.query("etoile == 'non'")[["note"]].to_string(index=False))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 d = Devoir("25", "notes25.xlsx")
#       2 d.mean("ds_1",
#       3     {"mpi": 11},
#       4     {"mpi" : 3.5}
#       5 )
#       6 d.mean("ds_2",
#       7     {"mpi": 11},
#       8     {"mpi" : 3.5}
#       9 )
#
# File /workspaces/notes/devoir.py:8, in Devoir.__init__(self, folder, file)
#       6 def __init__(self, folder, file):
#       7     self.folder, self.bareme = folder, {}
# ----> 8     self.df = pd.read_excel(f"{folder}/{file}", sheet_name=None)
#      10     for ds in self.df:
#      11         if ds == "id": continue
#
# File /workspaces/notes/.venv/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# ...

# %%
d.df[ds][["rang", "nom", "prenom", "note"]].sort_values("note", ascending=False).to_html("ds5.html", index=False)
