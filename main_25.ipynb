# %%
# %load_ext autoreload
# %autoreload 2
from devoir import Devoir

# %%
d = Devoir("25", "notes25.xlsx")
d.mean("ds_1", 
    {"mpi": 11},
    {"mpi" : 3.5}
)
d.mean("ds_2", 
    {"mpi": 11},
    {"mpi" : 3.5}
)
d.mean("ds_3", 
    {"mpi": 11},
    {"mpi" : 3.25}
)
dd = d.anonymize()
ds = "ds_3"
classe = "mpi"
# # dc = dd["option"]["2"]["df"].query("classe == 'mpp'")
dc = d.df[ds] #.query(f"classe == '{classe}' ")
print(dc[["note", "nom", "prenom"]].to_string(index=False))
dc.query("etoile == 'oui'")[["note"]].to_clipboard(index=False, header=None)  #, "nom"]]
# Out:
#  note               nom      prenom
#  10.5           Anestis       Timéo
#  13.9           Anjuere       Jarod
#  11.7        Ballandras        Rémi
#   9.6           Barbier     Matisse
#  11.9           Bernard      Axelle
#   9.7           Bernard        Paul
#  12.5          Berthail        Mael
#  14.6           Berthet      Julien
#   5.6          Bessaiah      Bachir
#   4.2         Bladehane    Mouhamed
#  13.1         Bogomolov      Dmitry
#  17.4           Bontron        Mael
#  15.6  Cherkaoui Jaouad      Mamoun
#  11.1          Dinsdale      Fabian
#  13.0             Duret       Anaïs
#  14.1  Fauchere--Collin        Alex
#  13.4          Goffinet     Phileas
#   8.5         Guillaume       Yahel
#  10.1            Horard     Clément
#   7.8           Jacquet     Lou-Ann
#  12.1         Jiva Lila       Rehan
#   9.3             Klein      Alexis
#  11.7           Lagadec         Léo
#   8.7             Menai        Rami
#   9.3           Monnier       Clara
#  17.4             Noury       Artus
#   4.7 Penet De Monterno     Armelle
#  14.3            Peyrin      Calvin
#   7.6              Picq      Adrien
#  11.4          Pioteyry     Tristan
#  11.5         Rouillard     Gautier
#  16.1         Samaranch        Elio
#   7.7           Sanchez      Arnaud
#   6.2    Soucaze-Soudat     Mathieu
#   8.7         Spraggins Christopher
#  10.0           Tessier       Lubin
#  14.0            Trabet      Mathis
#  10.9     Van De Steene      Nathan
#   9.1            Yamani      Sophie
# /Users/quentinfortier/Documents/cours/notes/devoir.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.statut.replace({"left_only": "absent", "right_only": "inconnu", "both": "présent"}, inplace=True)
# /Users/quentinfortier/Documents/cours/notes/devoir.py:19: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df.statut.replace({"left_only": "absent", "right_only": "inconnu", "both": "présent"}, inplace=True)
# /Users/quentinfortier/Documents/cours/notes/devoir.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.statut.replace({"left_only": "absent", "right_only": "inconnu", "both": "présent"}, inplace=True)
# /Users/quentinfortier/Documents/cours/notes/devoir.py:19: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df.statut.replace({"left_only": "absent", "right_only": "inconnu", "both": "présent"}, inplace=True)
# /Users/quentinfortier/Documents/cours/notes/devoir.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.statut.replace({"left_only": "absent", "right_only": "inconnu", "both": "présent"}, inplace=True)
# /Users/quentinfortier/Documents/cours/notes/devoir.py:19: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df.statut.replace({"left_only": "absent", "right_only": "inconnu", "both": "présent"}, inplace=True)

# %%
7.7
7.7
9.3
12.3
8.7
9.6
9.4
9.0
9.2
9.9
8.1
7.8
14.1
7.5
7.5
9.6
10.9
9.0

# %%
12.5
16.6
13.1
15.1
19.5
12.7
17.2
16.4
13.6
11.0
18.1
11.9
13.6
10.8
15.8
8.8
11.4
9.4
13.5
11.2
14.9
10.4
# Out:
# 14.2

# %%
d.df[ds][["rang", "nom", "prenom", "note"]].sort_values("note", ascending=False).to_html("ds5.html", index=False)
